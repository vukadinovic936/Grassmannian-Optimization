# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = lambda x,y: (2*x/(1+x**2+y**2) , 2*y/(1+x**2+y**2))

# %% [markdown]
# ## Generate points such that $x^2+y^2<1$

# %%
points_to_generate=2000
t = np.random.uniform(-1/2 * np.pi,3/2 * np.pi ,points_to_generate)
X = np.cos(t)
Y = np.cos(t)*np.sin(t)
#Y = np.random.uniform(-1,1,points_to_generate)
#to_remove=[]
#for i in range(points_to_generate):
#	if X[i]**2 + Y[i]**2 >=1:
#		to_remove.append(i)

# %%
X = np.delete(X,to_remove)
Y = np.delete(Y,to_remove)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-92325e98cc11> in <module>
# ----> 1 X = np.delete(X,to_remove)
#       2 Y = np.delete(Y,to_remove)
#
# NameError: name 'to_remove' is not defined

# %%
plt.scatter(X,Y)

# %%
plt.scatter(f(X,Y)[0],f(X,Y)[1])

# %%
plt.scatter(X,Y,c='b')
plt.scatter(f(X,Y)[0],f(X,Y)[1],c='r')
plt.show()
